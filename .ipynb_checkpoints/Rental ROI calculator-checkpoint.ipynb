# %%
 # Better to have input flow in initial function or in individual functions..
# Do I have seperate dictionaries for incomes, expenses and total cash investment?
import time
class RentalCalc():
    
    
    def __init__(self, income, expenses, monthlyCash, cashInvest, finalRoi, annualFlow):
        
        self.income = income
        self.expenses = expenses
        self.monthlyCash = monthlyCash
        self.cashInvest = cashInvest
        self.finalRoi = finalRoi
        self.annualFlow = annualFlow
        
        
    def personalInvest(self):
        
        print("\nNext we need our total investment from the owner!\n\n\n")
        almostDone = input('What will your total up front investment be?\n\nThis includes down payment:\nClosing costs:\nand any additional money out of pocket:\n')
        self.cashInvest = almostDone
        print(f'Okay calcualting.....\n\n\n\n')
        paybackPeriod = (float(self.annualFlow / float(self.cashInvest)))
        self.finalRoi = paybackPeriod
        print(self.finalRoi)
            
        if self.finalRoi < 0.06:
            print("Lets try another property! This isn't worth the investment!")
        else:
            print("This is a good deal!")
                
        while True:
            
            final = input("Would you like to look into another rental? Y/N")
            for i in final:
                if i.lower() == "n":
                    print('Okay have a nice day!')
                    return

                elif i.lower() == "y":
                    RentalCalc.moneyInOut(self)
                    
         # Total investment - Take input for down payment, closing costs and any additional money out of pocket -
         # Formula that takes Total investment and divides by Annual Cash Flow.
         # Link to lending services where input for total investments is added.
         # Have a Pre defined ROI percentage and compare our Cash on Cash(cashInvest) to it. 
         # Bring all together.. If it is above preset ROI, good deal f'string. If it is below, bad deal f'string.
         # Loop back to top asking if there is another investment oppertunity they want to calculate...
    
    def cashFlow(self):
        
        print(f'Okay we now have your Incomes and Expenses.. \n\n\n')
        
        
        difference = (int(self.income) - int(self.expenses))
        self.monthlyCash = difference    
        print(f'Here is your monthly cash flow!\n{self.monthlyCash}\n')
                            
        self.annualFlow = (int(self.monthlyCash) * (12))
        print(f"\nWe have taken your monthly cash flow and multiplied by 12 for yearly cash flow...")
        print("$" + str(self.annualFlow))
            
            
            
        RentalCalc.personalInvest(self)
        # Formula for income - expenses, then multiplied(*) by 12 months
        # Link to lending service function where input for cashflow is added -

        
    def moneyInOut(self):
        
        print("Welcome! We would like to help you determine the ROI for your rental property!\n")
        time.sleep(.3)
        incomes = input("First we need some information.. What is your total income for this property every month? \n$")
        self.income = incomes
            
        print(f'Okay we have your total monthly income!')
            
        # Input for rental income per month - 
        # Formula for total monthly incomes - 
        # Formula for adding total monthly incomes -
        # Link to lending service function where input for incomes is added -
        
        print("Next, lets enter all of your expenses per month! \n")
        bills = input("Please enter your total monthly expenses! \n$")
        self.expenses = bills
        print(f'Ok we have your totals:\nMonthly Income-{self.income}\nMonthly Expenses-{self.expenses}')
        
        RentalCalc.cashFlow(self)
        # Taxes, insurance, utilities, repairs, mortgage.
        # Maybe add HOA or prop management fee's
        # Formula for adding all expenses per month.
        # Assign above formula to attribute or value..
        # Link with incomes for the cashflow.
        # Link to lending service function where input for expenses is added -
    


    
                




roi = RentalCalc([],[],[],[],[],[])


roi.moneyInOut()
# Out:
# Welcome! We would like to help you determine the ROI for your rental property!
#
# First we need some information.. What is your total income for this property every month?
# $1000
# Okay we have your total monthly income!
# Next, lets enter all of your expenses per month!
#
# Please enter your total monthly expenses!
# $500
# Ok we have your totals:
# Monthly Income-1000
# Monthly Expenses-500
# Okay we now have your Incomes and Expenses..
#
#
#
# Here is your monthly cash flow!
# 500
#
#
# We have taken your monthly cash flow and multiplied by 12 for yearly cash flow...
# $6000
#
# Next we need our total investment from the owner!
#
#
#
# What will your total up front investment be?
#
# This includes down payment:
# Closing costs:
# and any additional money out of pocket:
# 1000000
# Okay calcualting.....
#
#
#
#
# 0.006
# Lets try another property! This isn't worth the investment!
# Would you like to look into another rental? Y/Nn
# Okay have a nice day!
